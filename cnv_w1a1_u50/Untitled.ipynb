# %%
from pynq import Overlay

ol = Overlay("bitstreams/a_u280_10cu.xclbin")
ol?
# Out:
# Type:            Overlay
# String form:     <pynq.overlay.Overlay object at 0x7f6859b62590>
# File:            ~/octoray/env/lib/python3.7/site-packages/pynq/overlay.py
# Docstring:
# Default documentation for overlay bitstreams/a_u280_10cu.xclbin. The following
# attributes are available on this overlay:
#
# IP Blocks
# ----------
# idma0                : pynq.overlay.DefaultIP
# idma1                : pynq.overlay.DefaultIP
# idma2                : pynq.overlay.DefaultIP
# idma3                : pynq.overlay.DefaultIP
# idma4                : pynq.overlay.DefaultIP
# idma5                : pynq.overlay.DefaultIP
# idma6                : pynq.overlay.DefaultIP
# idma7                : pynq.overlay.DefaultIP
# idma8                : pynq.overlay.DefaultIP
# idma9                : pynq.overlay.DefaultIP
# odma0                : pynq.overlay.DefaultIP
# odma1                : pynq.overlay.DefaultIP
# odma2                : pynq.overlay.DefaultIP
# ...
